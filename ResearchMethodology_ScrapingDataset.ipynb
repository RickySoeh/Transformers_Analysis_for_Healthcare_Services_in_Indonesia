# %%
from google_play_scraper import reviews, Sort
import pandas as pd
import random
import time

# Only Alodokter and Halodoc
apps = {
    "Halodoc": "com.linkdokter.halodoc.android",
    "Alodokter": "com.alodokter.android"
}

# Each app will contribute exactly 600 reviews per rating (total 3,000 per app)
target_per_rating = 800

def scrape_app_balanced(app_name, app_id):
    print(f"\n🔍 Scraping {app_name}...")
    continuation_token = None
    app_reviews = {1: [], 2: [], 3: [], 4: [], 5: []}

    while any(len(app_reviews[r]) < target_per_rating for r in range(1, 6)):
        result, continuation_token = reviews(
            app_id,
            lang='id',
            country='id',
            sort=Sort.NEWEST,
            count=200,
            continuation_token=continuation_token
        )

        if not result:
            print(f"⚠️ No more reviews for {app_name}.")
            break

        for r in result:
            rating = r["score"]
            if len(app_reviews[rating]) < target_per_rating:
                app_reviews[rating].append({
                    "application": app_name,
                    "review": r["content"],
                    "rating": rating
                })

        print(f"{app_name} rating counts: {[len(app_reviews[r]) for r in range(1, 6)]}")
        if not continuation_token:
            break
        time.sleep(random.uniform(1.0, 2.0))

    combined_reviews = sum(app_reviews.values(), [])
    print(f"✅ {app_name} total reviews collected: {len(combined_reviews)}")
    return combined_reviews

# Collect balanced reviews separately
all_reviews = []
for app_name, app_id in apps.items():
    reviews_data = scrape_app_balanced(app_name, app_id)
    all_reviews.extend(reviews_data)

# Shuffle and save
df = pd.DataFrame(all_reviews)
df = df.sample(frac=1).reset_index(drop=True)
df.to_csv("alodokter_halodoc_balanced_8000.csv", index=False)

print(f"\n🎉 Final dataset saved: {len(df)} reviews (4,000 per app, 800 per rating)")
# Out:
# 🔍 Scraping Halodoc...
# Halodoc rating counts: [16, 1, 2, 14, 167]
# Halodoc rating counts: [35, 1, 5, 18, 341]
# Halodoc rating counts: [58, 4, 10, 30, 498]
# Halodoc rating counts: [72, 8, 12, 36, 672]
# Halodoc rating counts: [90, 10, 14, 44, 800]
# Halodoc rating counts: [111, 14, 18, 54, 800]
# Halodoc rating counts: [123, 15, 23, 63, 800]
# Halodoc rating counts: [138, 19, 30, 71, 800]
# Halodoc rating counts: [154, 22, 35, 84, 800]
# Halodoc rating counts: [162, 27, 39, 96, 800]
# Halodoc rating counts: [176, 33, 39, 112, 800]
# Halodoc rating counts: [189, 34, 42, 122, 800]
# Halodoc rating counts: [206, 36, 47, 132, 800]
# Halodoc rating counts: [216, 39, 48, 147, 800]
# Halodoc rating counts: [229, 41, 53, 156, 800]
# Halodoc rating counts: [243, 45, 54, 169, 800]
# Halodoc rating counts: [257, 48, 57, 181, 800]
# Halodoc rating counts: [272, 49, 59, 190, 800]
# Halodoc rating counts: [281, 53, 61, 201, 800]
# Halodoc rating counts: [293, 57, 62, 215, 800]
# Halodoc rating counts: [304, 62, 65, 224, 800]
# Halodoc rating counts: [318, 65, 66, 239, 800]
# Halodoc rating counts: [331, 67, 71, 250, 800]
# Halodoc rating counts: [350, 67, 74, 259, 800]
# Halodoc rating counts: [365, 70, 78, 265, 800]
# Halodoc rating counts: [383, 72, 82, 274, 800]
# Halodoc rating counts: [393, 74, 84, 285, 800]
# Halodoc rating counts: [409, 79, 86, 301, 800]
# Halodoc rating counts: [426, 80, 88, 310, 800]
# Halodoc rating counts: [439, 81, 91, 320, 800]
# Halodoc rating counts: [447, 83, 96, 327, 800]
# Halodoc rating counts: [468, 87, 103, 341, 800]
# Halodoc rating counts: [488, 90, 106, 350, 800]
# Halodoc rating counts: [513, 93, 112, 363, 800]
# Halodoc rating counts: [528, 93, 117, 378, 800]
# Halodoc rating counts: [544, 96, 120, 389, 800]
# Halodoc rating counts: [557, 99, 122, 401, 800]
# Halodoc rating counts: [571, 103, 122, 410, 800]
# Halodoc rating counts: [584, 104, 123, 421, 800]
# Halodoc rating counts: [602, 106, 125, 434, 800]
# Halodoc rating counts: [617, 113, 127, 442, 800]
# Halodoc rating counts: [632, 114, 131, 446, 800]
# Halodoc rating counts: [653, 119, 135, 461, 800]
# Halodoc rating counts: [674, 122, 137, 471, 800]
# Halodoc rating counts: [693, 123, 138, 482, 800]
# Halodoc rating counts: [711, 129, 140, 489, 800]
# Halodoc rating counts: [724, 133, 141, 502, 800]
# Halodoc rating counts: [747, 135, 145, 511, 800]
# Halodoc rating counts: [769, 137, 147, 524, 800]
# Halodoc rating counts: [787, 140, 150, 536, 800]
# Halodoc rating counts: [800, 142, 155, 546, 800]
# Halodoc rating counts: [800, 144, 157, 561, 800]
# Halodoc rating counts: [800, 149, 160, 574, 800]
# Halodoc rating counts: [800, 153, 166, 584, 800]
# Halodoc rating counts: [800, 160, 173, 592, 800]
# Halodoc rating counts: [800, 163, 175, 599, 800]
# Halodoc rating counts: [800, 167, 178, 610, 800]
# Halodoc rating counts: [800, 174, 183, 617, 800]
# Halodoc rating counts: [800, 176, 187, 627, 800]
# Halodoc rating counts: [800, 180, 194, 633, 800]
# Halodoc rating counts: [800, 183, 199, 644, 800]
# Halodoc rating counts: [800, 189, 200, 656, 800]
# Halodoc rating counts: [800, 191, 202, 671, 800]
# Halodoc rating counts: [800, 195, 206, 682, 800]
# Halodoc rating counts: [800, 199, 211, 691, 800]
# Halodoc rating counts: [800, 200, 217, 704, 800]
# Halodoc rating counts: [800, 203, 222, 714, 800]
# Halodoc rating counts: [800, 205, 227, 722, 800]
# Halodoc rating counts: [800, 211, 230, 729, 800]
# Halodoc rating counts: [800, 217, 233, 739, 800]
# Halodoc rating counts: [800, 219, 235, 745, 800]
# Halodoc rating counts: [800, 221, 240, 755, 800]
# Halodoc rating counts: [800, 227, 241, 767, 800]
# Halodoc rating counts: [800, 228, 244, 773, 800]
# Halodoc rating counts: [800, 229, 250, 778, 800]
# Halodoc rating counts: [800, 234, 251, 790, 800]
# Halodoc rating counts: [800, 243, 259, 800, 800]
# Halodoc rating counts: [800, 245, 262, 800, 800]
# Halodoc rating counts: [800, 249, 265, 800, 800]
# Halodoc rating counts: [800, 251, 269, 800, 800]
# Halodoc rating counts: [800, 254, 270, 800, 800]
# Halodoc rating counts: [800, 257, 271, 800, 800]
# Halodoc rating counts: [800, 262, 273, 800, 800]
# Halodoc rating counts: [800, 263, 275, 800, 800]
# Halodoc rating counts: [800, 264, 279, 800, 800]
# Halodoc rating counts: [800, 268, 283, 800, 800]
# Halodoc rating counts: [800, 272, 287, 800, 800]
# Halodoc rating counts: [800, 273, 293, 800, 800]
# Halodoc rating counts: [800, 273, 299, 800, 800]
# Halodoc rating counts: [800, 280, 304, 800, 800]
# Halodoc rating counts: [800, 280, 308, 800, 800]
# Halodoc rating counts: [800, 285, 312, 800, 800]
# Halodoc rating counts: [800, 289, 315, 800, 800]
# Halodoc rating counts: [800, 291, 316, 800, 800]
# Halodoc rating counts: [800, 295, 318, 800, 800]
# Halodoc rating counts: [800, 299, 323, 800, 800]
# Halodoc rating counts: [800, 300, 327, 800, 800]
# Halodoc rating counts: [800, 303, 328, 800, 800]
# Halodoc rating counts: [800, 304, 331, 800, 800]
# Halodoc rating counts: [800, 307, 335, 800, 800]
# Halodoc rating counts: [800, 309, 340, 800, 800]
# Halodoc rating counts: [800, 312, 341, 800, 800]
# Halodoc rating counts: [800, 313, 344, 800, 800]
# Halodoc rating counts: [800, 317, 346, 800, 800]
# Halodoc rating counts: [800, 317, 349, 800, 800]
# Halodoc rating counts: [800, 320, 351, 800, 800]
# Halodoc rating counts: [800, 325, 354, 800, 800]
# Halodoc rating counts: [800, 328, 358, 800, 800]
# Halodoc rating counts: [800, 332, 360, 800, 800]
# Halodoc rating counts: [800, 333, 364, 800, 800]
# Halodoc rating counts: [800, 335, 368, 800, 800]
# Halodoc rating counts: [800, 340, 371, 800, 800]
# Halodoc rating counts: [800, 343, 374, 800, 800]
# Halodoc rating counts: [800, 347, 377, 800, 800]
# Halodoc rating counts: [800, 349, 382, 800, 800]
# Halodoc rating counts: [800, 355, 387, 800, 800]
# Halodoc rating counts: [800, 361, 393, 800, 800]
# Halodoc rating counts: [800, 363, 396, 800, 800]
# Halodoc rating counts: [800, 371, 399, 800, 800]
# Halodoc rating counts: [800, 374, 404, 800, 800]
# Halodoc rating counts: [800, 378, 411, 800, 800]
# Halodoc rating counts: [800, 381, 419, 800, 800]
# Halodoc rating counts: [800, 384, 425, 800, 800]
# Halodoc rating counts: [800, 387, 427, 800, 800]
# Halodoc rating counts: [800, 390, 428, 800, 800]
# Halodoc rating counts: [800, 395, 434, 800, 800]
# Halodoc rating counts: [800, 398, 440, 800, 800]
# Halodoc rating counts: [800, 400, 445, 800, 800]
# Halodoc rating counts: [800, 404, 449, 800, 800]
# Halodoc rating counts: [800, 405, 452, 800, 800]
# Halodoc rating counts: [800, 413, 457, 800, 800]
# Halodoc rating counts: [800, 417, 465, 800, 800]
# Halodoc rating counts: [800, 421, 473, 800, 800]
# Halodoc rating counts: [800, 423, 478, 800, 800]
# Halodoc rating counts: [800, 427, 482, 800, 800]
# Halodoc rating counts: [800, 432, 489, 800, 800]
# Halodoc rating counts: [800, 436, 493, 800, 800]
# Halodoc rating counts: [800, 439, 498, 800, 800]
# Halodoc rating counts: [800, 445, 505, 800, 800]
# Halodoc rating counts: [800, 447, 512, 800, 800]
# Halodoc rating counts: [800, 449, 514, 800, 800]
# Halodoc rating counts: [800, 455, 517, 800, 800]
# Halodoc rating counts: [800, 462, 519, 800, 800]
# Halodoc rating counts: [800, 464, 525, 800, 800]
# Halodoc rating counts: [800, 471, 532, 800, 800]
# Halodoc rating counts: [800, 474, 535, 800, 800]
# Halodoc rating counts: [800, 474, 539, 800, 800]
# Halodoc rating counts: [800, 477, 543, 800, 800]
# Halodoc rating counts: [800, 479, 548, 800, 800]
# Halodoc rating counts: [800, 483, 551, 800, 800]
# Halodoc rating counts: [800, 487, 554, 800, 800]
# Halodoc rating counts: [800, 487, 563, 800, 800]
# Halodoc rating counts: [800, 491, 567, 800, 800]
# Halodoc rating counts: [800, 494, 572, 800, 800]
# Halodoc rating counts: [800, 502, 574, 800, 800]
# Halodoc rating counts: [800, 503, 577, 800, 800]
# Halodoc rating counts: [800, 507, 583, 800, 800]
# Halodoc rating counts: [800, 511, 588, 800, 800]
# Halodoc rating counts: [800, 516, 595, 800, 800]
# Halodoc rating counts: [800, 519, 598, 800, 800]
# Halodoc rating counts: [800, 523, 602, 800, 800]
# Halodoc rating counts: [800, 526, 605, 800, 800]
# Halodoc rating counts: [800, 527, 607, 800, 800]
# Halodoc rating counts: [800, 528, 613, 800, 800]
# Halodoc rating counts: [800, 532, 619, 800, 800]
# Halodoc rating counts: [800, 534, 624, 800, 800]
# Halodoc rating counts: [800, 536, 628, 800, 800]
# Halodoc rating counts: [800, 537, 630, 800, 800]
# Halodoc rating counts: [800, 540, 636, 800, 800]
# Halodoc rating counts: [800, 542, 639, 800, 800]
# Halodoc rating counts: [800, 542, 644, 800, 800]
# Halodoc rating counts: [800, 542, 651, 800, 800]
# Halodoc rating counts: [800, 546, 658, 800, 800]
# Halodoc rating counts: [800, 550, 660, 800, 800]
# Halodoc rating counts: [800, 556, 668, 800, 800]
# Halodoc rating counts: [800, 559, 673, 800, 800]
# Halodoc rating counts: [800, 562, 678, 800, 800]
# Halodoc rating counts: [800, 568, 681, 800, 800]
# Halodoc rating counts: [800, 570, 682, 800, 800]
# Halodoc rating counts: [800, 570, 690, 800, 800]
# Halodoc rating counts: [800, 573, 692, 800, 800]
# Halodoc rating counts: [800, 575, 694, 800, 800]
# Halodoc rating counts: [800, 581, 696, 800, 800]
# Halodoc rating counts: [800, 586, 701, 800, 800]
# Halodoc rating counts: [800, 588, 704, 800, 800]
# Halodoc rating counts: [800, 590, 708, 800, 800]
# Halodoc rating counts: [800, 592, 714, 800, 800]
# Halodoc rating counts: [800, 595, 715, 800, 800]
# Halodoc rating counts: [800, 596, 717, 800, 800]
# Halodoc rating counts: [800, 599, 719, 800, 800]
# Halodoc rating counts: [800, 600, 722, 800, 800]
# Halodoc rating counts: [800, 601, 727, 800, 800]
# Halodoc rating counts: [800, 603, 729, 800, 800]
# Halodoc rating counts: [800, 607, 731, 800, 800]
# Halodoc rating counts: [800, 609, 731, 800, 800]
# Halodoc rating counts: [800, 614, 734, 800, 800]
# Halodoc rating counts: [800, 614, 736, 800, 800]
# Halodoc rating counts: [800, 615, 741, 800, 800]
# Halodoc rating counts: [800, 619, 744, 800, 800]
# Halodoc rating counts: [800, 619, 751, 800, 800]
# Halodoc rating counts: [800, 620, 756, 800, 800]
# Halodoc rating counts: [800, 621, 757, 800, 800]
# Halodoc rating counts: [800, 622, 762, 800, 800]
# Halodoc rating counts: [800, 624, 765, 800, 800]
# Halodoc rating counts: [800, 630, 773, 800, 800]
# Halodoc rating counts: [800, 632, 775, 800, 800]
# Halodoc rating counts: [800, 632, 779, 800, 800]
# Halodoc rating counts: [800, 634, 783, 800, 800]
# Halodoc rating counts: [800, 635, 786, 800, 800]
# Halodoc rating counts: [800, 636, 793, 800, 800]
# Halodoc rating counts: [800, 637, 796, 800, 800]
# Halodoc rating counts: [800, 640, 800, 800, 800]
# Halodoc rating counts: [800, 642, 800, 800, 800]
# Halodoc rating counts: [800, 643, 800, 800, 800]
# Halodoc rating counts: [800, 643, 800, 800, 800]
# Halodoc rating counts: [800, 645, 800, 800, 800]
# Halodoc rating counts: [800, 646, 800, 800, 800]
# Halodoc rating counts: [800, 646, 800, 800, 800]
# Halodoc rating counts: [800, 647, 800, 800, 800]
# Halodoc rating counts: [800, 650, 800, 800, 800]
# Halodoc rating counts: [800, 651, 800, 800, 800]
# Halodoc rating counts: [800, 653, 800, 800, 800]
# Halodoc rating counts: [800, 653, 800, 800, 800]
# Halodoc rating counts: [800, 655, 800, 800, 800]
# Halodoc rating counts: [800, 658, 800, 800, 800]
# Halodoc rating counts: [800, 660, 800, 800, 800]
# Halodoc rating counts: [800, 663, 800, 800, 800]
# Halodoc rating counts: [800, 663, 800, 800, 800]
# Halodoc rating counts: [800, 664, 800, 800, 800]
# Halodoc rating counts: [800, 666, 800, 800, 800]
# Halodoc rating counts: [800, 666, 800, 800, 800]
# Halodoc rating counts: [800, 668, 800, 800, 800]
# Halodoc rating counts: [800, 671, 800, 800, 800]
# Halodoc rating counts: [800, 672, 800, 800, 800]
# Halodoc rating counts: [800, 672, 800, 800, 800]
# Halodoc rating counts: [800, 674, 800, 800, 800]
# Halodoc rating counts: [800, 675, 800, 800, 800]
# Halodoc rating counts: [800, 678, 800, 800, 800]
# Halodoc rating counts: [800, 681, 800, 800, 800]
# Halodoc rating counts: [800, 684, 800, 800, 800]
# Halodoc rating counts: [800, 687, 800, 800, 800]
# Halodoc rating counts: [800, 689, 800, 800, 800]
# Halodoc rating counts: [800, 690, 800, 800, 800]
# Halodoc rating counts: [800, 690, 800, 800, 800]
# Halodoc rating counts: [800, 690, 800, 800, 800]
# Halodoc rating counts: [800, 692, 800, 800, 800]
# Halodoc rating counts: [800, 696, 800, 800, 800]
# Halodoc rating counts: [800, 700, 800, 800, 800]
# Halodoc rating counts: [800, 700, 800, 800, 800]
# Halodoc rating counts: [800, 701, 800, 800, 800]
# Halodoc rating counts: [800, 703, 800, 800, 800]
# Halodoc rating counts: [800, 705, 800, 800, 800]
# Halodoc rating counts: [800, 708, 800, 800, 800]
# Halodoc rating counts: [800, 708, 800, 800, 800]
# Halodoc rating counts: [800, 710, 800, 800, 800]
# Halodoc rating counts: [800, 713, 800, 800, 800]
# Halodoc rating counts: [800, 715, 800, 800, 800]
# Halodoc rating counts: [800, 716, 800, 800, 800]
# Halodoc rating counts: [800, 717, 800, 800, 800]
# Halodoc rating counts: [800, 722, 800, 800, 800]
# Halodoc rating counts: [800, 722, 800, 800, 800]
# Halodoc rating counts: [800, 722, 800, 800, 800]
# Halodoc rating counts: [800, 724, 800, 800, 800]
# Halodoc rating counts: [800, 727, 800, 800, 800]
# Halodoc rating counts: [800, 727, 800, 800, 800]
# Halodoc rating counts: [800, 728, 800, 800, 800]
# Halodoc rating counts: [800, 731, 800, 800, 800]
# Halodoc rating counts: [800, 735, 800, 800, 800]
# Halodoc rating counts: [800, 735, 800, 800, 800]
# Halodoc rating counts: [800, 737, 800, 800, 800]
# Halodoc rating counts: [800, 738, 800, 800, 800]
# Halodoc rating counts: [800, 741, 800, 800, 800]
# Halodoc rating counts: [800, 741, 800, 800, 800]
# Halodoc rating counts: [800, 742, 800, 800, 800]
# Halodoc rating counts: [800, 743, 800, 800, 800]
# Halodoc rating counts: [800, 745, 800, 800, 800]
# Halodoc rating counts: [800, 746, 800, 800, 800]
# Halodoc rating counts: [800, 749, 800, 800, 800]
# Halodoc rating counts: [800, 750, 800, 800, 800]
# Halodoc rating counts: [800, 751, 800, 800, 800]
# Halodoc rating counts: [800, 753, 800, 800, 800]
# Halodoc rating counts: [800, 756, 800, 800, 800]
# Halodoc rating counts: [800, 756, 800, 800, 800]
# Halodoc rating counts: [800, 757, 800, 800, 800]
# Halodoc rating counts: [800, 757, 800, 800, 800]
# Halodoc rating counts: [800, 758, 800, 800, 800]
# Halodoc rating counts: [800, 758, 800, 800, 800]
# Halodoc rating counts: [800, 758, 800, 800, 800]
# Halodoc rating counts: [800, 760, 800, 800, 800]
# Halodoc rating counts: [800, 761, 800, 800, 800]
# Halodoc rating counts: [800, 762, 800, 800, 800]
# Halodoc rating counts: [800, 763, 800, 800, 800]
# Halodoc rating counts: [800, 766, 800, 800, 800]
# Halodoc rating counts: [800, 767, 800, 800, 800]
# Halodoc rating counts: [800, 768, 800, 800, 800]
# Halodoc rating counts: [800, 771, 800, 800, 800]
# Halodoc rating counts: [800, 771, 800, 800, 800]
# Halodoc rating counts: [800, 772, 800, 800, 800]
# Halodoc rating counts: [800, 773, 800, 800, 800]
# Halodoc rating counts: [800, 773, 800, 800, 800]
# Halodoc rating counts: [800, 775, 800, 800, 800]
# Halodoc rating counts: [800, 775, 800, 800, 800]
# Halodoc rating counts: [800, 775, 800, 800, 800]
# Halodoc rating counts: [800, 775, 800, 800, 800]
# Halodoc rating counts: [800, 777, 800, 800, 800]
# Halodoc rating counts: [800, 778, 800, 800, 800]
# Halodoc rating counts: [800, 780, 800, 800, 800]
# Halodoc rating counts: [800, 786, 800, 800, 800]
# Halodoc rating counts: [800, 788, 800, 800, 800]
# Halodoc rating counts: [800, 789, 800, 800, 800]
# Halodoc rating counts: [800, 790, 800, 800, 800]
# Halodoc rating counts: [800, 792, 800, 800, 800]
# Halodoc rating counts: [800, 794, 800, 800, 800]
# Halodoc rating counts: [800, 797, 800, 800, 800]
# Halodoc rating counts: [800, 799, 800, 800, 800]
# Halodoc rating counts: [800, 800, 800, 800, 800]
# ✅ Halodoc total reviews collected: 4000
#
# 🔍 Scraping Alodokter...
# Alodokter rating counts: [28, 5, 6, 10, 151]
# Alodokter rating counts: [55, 9, 15, 25, 296]
# Alodokter rating counts: [85, 15, 23, 36, 441]
# Alodokter rating counts: [114, 24, 28, 50, 584]
# Alodokter rating counts: [145, 28, 35, 57, 735]
# Alodokter rating counts: [177, 31, 37, 71, 800]
# Alodokter rating counts: [202, 34, 46, 82, 800]
# Alodokter rating counts: [235, 43, 49, 92, 800]
# Alodokter rating counts: [263, 50, 57, 101, 800]
# Alodokter rating counts: [292, 57, 65, 119, 800]
# Alodokter rating counts: [315, 61, 71, 126, 800]
# Alodokter rating counts: [343, 63, 76, 139, 800]
# Alodokter rating counts: [363, 64, 83, 150, 800]
# Alodokter rating counts: [387, 66, 87, 161, 800]
# Alodokter rating counts: [419, 72, 95, 176, 800]
# Alodokter rating counts: [456, 77, 99, 189, 800]
# Alodokter rating counts: [492, 81, 108, 202, 800]
# Alodokter rating counts: [521, 86, 117, 222, 800]
# Alodokter rating counts: [556, 96, 124, 232, 800]
# Alodokter rating counts: [586, 111, 131, 240, 800]
# Alodokter rating counts: [632, 121, 140, 247, 800]
# Alodokter rating counts: [676, 127, 145, 254, 800]
# Alodokter rating counts: [727, 131, 148, 269, 800]
# Alodokter rating counts: [775, 135, 156, 286, 800]
# Alodokter rating counts: [800, 143, 163, 295, 800]
# Alodokter rating counts: [800, 146, 174, 309, 800]
# Alodokter rating counts: [800, 155, 179, 325, 800]
# Alodokter rating counts: [800, 160, 186, 335, 800]
# Alodokter rating counts: [800, 165, 190, 341, 800]
# Alodokter rating counts: [800, 172, 196, 350, 800]
# Alodokter rating counts: [800, 177, 202, 362, 800]
# Alodokter rating counts: [800, 185, 208, 371, 800]
# Alodokter rating counts: [800, 193, 215, 386, 800]
# Alodokter rating counts: [800, 198, 221, 399, 800]
# Alodokter rating counts: [800, 201, 231, 408, 800]
# Alodokter rating counts: [800, 205, 237, 427, 800]
# Alodokter rating counts: [800, 213, 243, 437, 800]
# Alodokter rating counts: [800, 217, 253, 446, 800]
# Alodokter rating counts: [800, 223, 261, 461, 800]
# Alodokter rating counts: [800, 233, 269, 470, 800]
# Alodokter rating counts: [800, 238, 276, 480, 800]
# Alodokter rating counts: [800, 240, 279, 495, 800]
# Alodokter rating counts: [800, 243, 284, 507, 800]
# Alodokter rating counts: [800, 253, 290, 520, 800]
# Alodokter rating counts: [800, 258, 294, 537, 800]
# Alodokter rating counts: [800, 262, 300, 550, 800]
# Alodokter rating counts: [800, 267, 302, 569, 800]
# Alodokter rating counts: [800, 270, 310, 582, 800]
# Alodokter rating counts: [800, 277, 315, 593, 800]
# Alodokter rating counts: [800, 282, 319, 613, 800]
# Alodokter rating counts: [800, 284, 320, 633, 800]
# Alodokter rating counts: [800, 285, 323, 650, 800]
# Alodokter rating counts: [800, 287, 325, 669, 800]
# Alodokter rating counts: [800, 289, 328, 688, 800]
# Alodokter rating counts: [800, 292, 334, 707, 800]
# Alodokter rating counts: [800, 293, 341, 731, 800]
# Alodokter rating counts: [800, 294, 345, 751, 800]
# Alodokter rating counts: [800, 296, 349, 772, 800]
# Alodokter rating counts: [800, 297, 352, 778, 800]
# Alodokter rating counts: [800, 299, 359, 791, 800]
# Alodokter rating counts: [800, 301, 369, 800, 800]
# Alodokter rating counts: [800, 302, 374, 800, 800]
# Alodokter rating counts: [800, 303, 379, 800, 800]
# Alodokter rating counts: [800, 305, 385, 800, 800]
# Alodokter rating counts: [800, 306, 393, 800, 800]
# Alodokter rating counts: [800, 309, 398, 800, 800]
# Alodokter rating counts: [800, 315, 404, 800, 800]
# Alodokter rating counts: [800, 321, 408, 800, 800]
# Alodokter rating counts: [800, 325, 416, 800, 800]
# Alodokter rating counts: [800, 330, 418, 800, 800]
# Alodokter rating counts: [800, 332, 422, 800, 800]
# Alodokter rating counts: [800, 337, 431, 800, 800]
# Alodokter rating counts: [800, 339, 436, 800, 800]
# Alodokter rating counts: [800, 341, 442, 800, 800]
# Alodokter rating counts: [800, 344, 448, 800, 800]
# Alodokter rating counts: [800, 346, 459, 800, 800]
# Alodokter rating counts: [800, 353, 462, 800, 800]
# Alodokter rating counts: [800, 360, 470, 800, 800]
# Alodokter rating counts: [800, 363, 473, 800, 800]
# Alodokter rating counts: [800, 365, 477, 800, 800]
# Alodokter rating counts: [800, 367, 481, 800, 800]
# Alodokter rating counts: [800, 367, 486, 800, 800]
# Alodokter rating counts: [800, 369, 490, 800, 800]
# Alodokter rating counts: [800, 371, 499, 800, 800]
# Alodokter rating counts: [800, 373, 502, 800, 800]
# Alodokter rating counts: [800, 378, 507, 800, 800]
# Alodokter rating counts: [800, 379, 514, 800, 800]
# Alodokter rating counts: [800, 382, 518, 800, 800]
# Alodokter rating counts: [800, 383, 525, 800, 800]
# Alodokter rating counts: [800, 384, 533, 800, 800]
# Alodokter rating counts: [800, 388, 536, 800, 800]
# Alodokter rating counts: [800, 391, 540, 800, 800]
# Alodokter rating counts: [800, 392, 550, 800, 800]
# Alodokter rating counts: [800, 396, 558, 800, 800]
# Alodokter rating counts: [800, 400, 564, 800, 800]
# Alodokter rating counts: [800, 402, 571, 800, 800]
# Alodokter rating counts: [800, 405, 573, 800, 800]
# Alodokter rating counts: [800, 409, 579, 800, 800]
# Alodokter rating counts: [800, 411, 583, 800, 800]
# Alodokter rating counts: [800, 412, 586, 800, 800]
# Alodokter rating counts: [800, 418, 592, 800, 800]
# Alodokter rating counts: [800, 420, 594, 800, 800]
# Alodokter rating counts: [800, 424, 598, 800, 800]
# Alodokter rating counts: [800, 432, 605, 800, 800]
# Alodokter rating counts: [800, 433, 608, 800, 800]
# Alodokter rating counts: [800, 435, 609, 800, 800]
# Alodokter rating counts: [800, 440, 617, 800, 800]
# Alodokter rating counts: [800, 443, 620, 800, 800]
# Alodokter rating counts: [800, 447, 627, 800, 800]
# Alodokter rating counts: [800, 453, 628, 800, 800]
# Alodokter rating counts: [800, 458, 630, 800, 800]
# Alodokter rating counts: [800, 462, 639, 800, 800]
# Alodokter rating counts: [800, 469, 648, 800, 800]
# Alodokter rating counts: [800, 473, 652, 800, 800]
# Alodokter rating counts: [800, 478, 654, 800, 800]
# Alodokter rating counts: [800, 479, 659, 800, 800]
# Alodokter rating counts: [800, 481, 671, 800, 800]
# Alodokter rating counts: [800, 482, 678, 800, 800]
# Alodokter rating counts: [800, 482, 687, 800, 800]
# Alodokter rating counts: [800, 484, 697, 800, 800]
# Alodokter rating counts: [800, 488, 702, 800, 800]
# Alodokter rating counts: [800, 489, 703, 800, 800]
# Alodokter rating counts: [800, 495, 711, 800, 800]
# Alodokter rating counts: [800, 497, 716, 800, 800]
# Alodokter rating counts: [800, 498, 726, 800, 800]
# Alodokter rating counts: [800, 501, 730, 800, 800]
# Alodokter rating counts: [800, 504, 739, 800, 800]
# Alodokter rating counts: [800, 507, 745, 800, 800]
# Alodokter rating counts: [800, 509, 747, 800, 800]
# Alodokter rating counts: [800, 510, 748, 800, 800]
# Alodokter rating counts: [800, 517, 760, 800, 800]
# Alodokter rating counts: [800, 522, 773, 800, 800]
# Alodokter rating counts: [800, 525, 775, 800, 800]
# Alodokter rating counts: [800, 529, 780, 800, 800]
# Alodokter rating counts: [800, 535, 784, 800, 800]
# Alodokter rating counts: [800, 537, 786, 800, 800]
# Alodokter rating counts: [800, 540, 789, 800, 800]
# Alodokter rating counts: [800, 542, 800, 800, 800]
# Alodokter rating counts: [800, 546, 800, 800, 800]
# Alodokter rating counts: [800, 550, 800, 800, 800]
# Alodokter rating counts: [800, 556, 800, 800, 800]
# Alodokter rating counts: [800, 556, 800, 800, 800]
# Alodokter rating counts: [800, 559, 800, 800, 800]
# Alodokter rating counts: [800, 565, 800, 800, 800]
# Alodokter rating counts: [800, 571, 800, 800, 800]
# Alodokter rating counts: [800, 575, 800, 800, 800]
# Alodokter rating counts: [800, 585, 800, 800, 800]
# Alodokter rating counts: [800, 589, 800, 800, 800]
# Alodokter rating counts: [800, 592, 800, 800, 800]
# Alodokter rating counts: [800, 598, 800, 800, 800]
# Alodokter rating counts: [800, 600, 800, 800, 800]
# Alodokter rating counts: [800, 604, 800, 800, 800]
# Alodokter rating counts: [800, 605, 800, 800, 800]
# Alodokter rating counts: [800, 607, 800, 800, 800]
# Alodokter rating counts: [800, 608, 800, 800, 800]
# Alodokter rating counts: [800, 613, 800, 800, 800]
# Alodokter rating counts: [800, 614, 800, 800, 800]
# Alodokter rating counts: [800, 616, 800, 800, 800]
# Alodokter rating counts: [800, 621, 800, 800, 800]
# Alodokter rating counts: [800, 625, 800, 800, 800]
# Alodokter rating counts: [800, 626, 800, 800, 800]
# Alodokter rating counts: [800, 632, 800, 800, 800]
# Alodokter rating counts: [800, 635, 800, 800, 800]
# Alodokter rating counts: [800, 637, 800, 800, 800]
# Alodokter rating counts: [800, 640, 800, 800, 800]
# Alodokter rating counts: [800, 642, 800, 800, 800]
# Alodokter rating counts: [800, 644, 800, 800, 800]
# Alodokter rating counts: [800, 648, 800, 800, 800]
# Alodokter rating counts: [800, 650, 800, 800, 800]
# Alodokter rating counts: [800, 655, 800, 800, 800]
# Alodokter rating counts: [800, 655, 800, 800, 800]
# Alodokter rating counts: [800, 660, 800, 800, 800]
# Alodokter rating counts: [800, 662, 800, 800, 800]
# Alodokter rating counts: [800, 662, 800, 800, 800]
# Alodokter rating counts: [800, 664, 800, 800, 800]
# Alodokter rating counts: [800, 667, 800, 800, 800]
# Alodokter rating counts: [800, 674, 800, 800, 800]
# Alodokter rating counts: [800, 677, 800, 800, 800]
# Alodokter rating counts: [800, 681, 800, 800, 800]
# Alodokter rating counts: [800, 685, 800, 800, 800]
# Alodokter rating counts: [800, 688, 800, 800, 800]
# Alodokter rating counts: [800, 692, 800, 800, 800]
# Alodokter rating counts: [800, 695, 800, 800, 800]
# Alodokter rating counts: [800, 699, 800, 800, 800]
# Alodokter rating counts: [800, 704, 800, 800, 800]
# Alodokter rating counts: [800, 708, 800, 800, 800]
# Alodokter rating counts: [800, 712, 800, 800, 800]
# Alodokter rating counts: [800, 718, 800, 800, 800]
# Alodokter rating counts: [800, 719, 800, 800, 800]
# Alodokter rating counts: [800, 722, 800, 800, 800]
# Alodokter rating counts: [800, 725, 800, 800, 800]
# Alodokter rating counts: [800, 727, 800, 800, 800]
# Alodokter rating counts: [800, 730, 800, 800, 800]
# Alodokter rating counts: [800, 733, 800, 800, 800]
# Alodokter rating counts: [800, 739, 800, 800, 800]
# Alodokter rating counts: [800, 741, 800, 800, 800]
# Alodokter rating counts: [800, 745, 800, 800, 800]
# Alodokter rating counts: [800, 747, 800, 800, 800]
# Alodokter rating counts: [800, 749, 800, 800, 800]
# Alodokter rating counts: [800, 750, 800, 800, 800]
# Alodokter rating counts: [800, 756, 800, 800, 800]
# Alodokter rating counts: [800, 759, 800, 800, 800]
# Alodokter rating counts: [800, 765, 800, 800, 800]
# Alodokter rating counts: [800, 770, 800, 800, 800]
# Alodokter rating counts: [800, 776, 800, 800, 800]
# Alodokter rating counts: [800, 777, 800, 800, 800]
# Alodokter rating counts: [800, 780, 800, 800, 800]
# Alodokter rating counts: [800, 785, 800, 800, 800]
# Alodokter rating counts: [800, 787, 800, 800, 800]
# Alodokter rating counts: [800, 792, 800, 800, 800]
# Alodokter rating counts: [800, 795, 800, 800, 800]
# Alodokter rating counts: [800, 798, 800, 800, 800]
# Alodokter rating counts: [800, 800, 800, 800, 800]
# ✅ Alodokter total reviews collected: 4000
#
# 🎉 Final dataset saved: 8000 reviews (3,000 per app, 600 per rating)

# %%
pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.1 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7
